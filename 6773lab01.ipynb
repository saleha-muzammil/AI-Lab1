# %%
from typing import Union
# #q1
# Name=input("Enter Name")
# Age=input("Enter your age")
# print(f"Welcome {Name} Age: {Age}")


#q2
# NUM=int(input("Enter any number"))
# print("THE TYPE IS:", type(NUM))


# floatnum=float(input("Enter any float number"))
# print("THE TYPE IS:", type(floatnum))

# convertfloat=float(NUM)
# print("THE converted number type is :", type(convertfloat))



#q3
# list=["bmw","feraRri","apple"]
# list.append("Toyota")
# list.remove("bmw")
# for x in list:
#   print(x.upper())

# #q4
# list=["bmw","feraRri","apple"]
# a,b,c=list
# print(a)
# print(b)
# print(c)


#q5
# std={"Ali":100,"Ahmed":80,"Hammad":60 }
# for x in std:
#   print("Student Name:",x,"Marks:",std[x])

#q6
# List1 = input("Enter elements separated by space: ").split()
# List2 = input("Enter elements separated by space: ").split()
# List1 = [int(x) for x in List1]
# List2 = [int(x) for x in List2]
# a=set(List1)
# b=set(List2)

# union_list = a.union(b)
# print("Union lists:", union_list)

# intersection_list = a.intersection(b)
# print("Intersection lists:", intersection_list)

# difference_list = a.difference(b)
# print("difference_list a-b :", difference_list)

#q7
# num=int(input("Enter num"))
# if num%2==0 and num>0:
#   print("even and postive")
# elif num%2==0 and num<0:
#   print("even and negative")
# elif num%2!=0 and num>0:
#   print("odd and positive")
# else:
#   print("odd and negative")

#q8
# for x in range(1,50):
#   if x%3==0 and x%5==0:
#     print("FizzBuzz")
#   elif x%3==0:
#     print("Fizz")
#   elif x%5==0:
#     print("Buzz")
#   else:
#     print(x)

#q9
# num=int(input("Enter num"))
# def factorial(num):
#   fact=1
#   for x in range(1,num+1):
#     fact=fact*x
#   return fact

# print("Factorial of",num,"is",factorial(num))

#q10
# num=int(input("Enter num"))
# fact=1
# for x in range(2,int(num/2)):
#   if(num%x==0):
#     fact=2
# if(fact==1):
#   print("Prime Number")
# else:
#   print("Not Prime Number")

#q11
# List1 = input("Enter elements separated by space: ").split()
# List1 = [int(x) for x in List1]

# List2=[x*x for x in List1]
# print(List2)

#q12
# dict1={'a':1 ,'b':2}
# dict2={'c':3 ,'d':4}
# dict1.update(dict2)
# print(dict1)

#q13
# def remove_duplicates(List1):
#   unique_list = []
#   for item in List1:
#     if item not in unique_list:
#       unique_list.append(item)
#   print(unique_list)
# List1 = input("Enter elements separated by space: ").split()
# remove_duplicates(List1)

#q14
# p=input("Enter any string")
# p = p.replace(" ", "")
# p.lower()
# print(p)
# if p==p[::-1]:
#   print("Palindrome")
# else:
#   print("Not Palindrome")

#q15
# def Fibonacci(n):
#     if n == 0:
#         return 0
#     elif n == 1 or n == 2:
#         return 1
#     else:
#         return Fibonacci(n-1) + Fibonacci(n-2)

# Num=int(input("Enter num"))
# for x in range(0,Num):
#   print(Fibonacci(x))

#q16
# List1 = input("Enter elements separated by space: ").split()
# List1 = [int(x) for x in List1]

# sum=0
# for x in List1:
#   sum+=x

# print("Avg of list is",sum/len(List1))

#q17
# for x in range(1,11):
#   print(f"TABLE {x}")
#   for y in range(1,11):
#     print(x*y)

#q18
# std={"ALI":"0024","AHMED":"3201","HAMMAD":"1122" }
# name=input("Enter name")
# password=input("Enter password")

# exists=0
# for x in std:
#   if x==name:
#     exists=1

# if(exists==1):
#   if(std[name]==password):
#     print("Welcome")
#   else:
#     print("Invalid password ")
# else:
#   print("Invalid name")

#q19
# List1 = input("Enter elements separated by space: ").split()
# dictionary={}

# for x in List1:
#   if x in dictionary:
#     dictionary[x]+=1
#   else:
#     dictionary[x]=1

# print(dictionary)

#q20
# def convert_temperature():
#     choice = int(input("Enter 1 for Fahrenheit to Celsius conversion or 2 for Celsius to Fahrenheit conversion: "))
#     temp = float(input("Enter the temperature to convert: "))

#     if choice == 1:
#         converted_temp = (temp - 32) * 5 / 9
#         print(f"Fahrenheit to Celsius: {converted_temp}°C")
#     elif choice == 2:
#         converted_temp = (temp * 9 / 5) + 32
#         print(f"Celsius to Fahrenheit: {converted_temp}°F")

# convert_temperature()
# Out:
# Enter 1 for Fahrenheit to Celsius conversion or 2 for Celsius to Fahrenheit conversion: 1
# Enter the temperature to convert: 50
# Fahrenheit to Celsius: 10.0°C
